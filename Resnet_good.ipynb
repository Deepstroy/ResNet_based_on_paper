# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tqdm import tqdm
import os
import shutil

# !pip install tensorboardcolab
import tensorboardcolab

import sys
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)
# Using TensorFlow backend.

# %%
from IPython.display import clear_output, Image, display, HTML
import numpy as np    

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %% [markdown]
# # DataProvider

# %%
from tensorflow.keras.datasets.cifar10 import load_data
(train_x, train_y), (test_x, test_y) = load_data()

# %%
from tensorflow.keras.datasets.cifar10 import load_data
(train_x, train_y), (test_x, test_y) = load_data()

# rank2 -> rank1 
test_y = test_y.reshape(-1)
train_y = train_y.reshape(-1)

## normalization 
train_x, test_x = [x /255. for x in [train_x, test_x]]

# %%
import random

class DataProvider(object):
    def __init__(self, images, labels):
        self.n_sample = len(labels)
        self.queue = list(range(self.n_sample))
        random.shuffle(self.queue)

        self.images = images
        self.labels = labels
        self.epoch_count = 0

    def next_batch(self, batch_size):
        if len(self.queue) < batch_size:
            self.queue = list(range(self.n_sample))
            self.epoch_count += 1
        target_indices = self.queue[:batch_size]
        del self.queue[:batch_size]
        return self.images[target_indices], self.labels[target_indices]

# %%
def image_augmentation(image, is_training, crop_h, crop_w):

    def _aug_with_train(input_x, crop_height, crop_width):
        img_h, img_w, ch = list(map(int, input_x.get_shape()[:]))

        pad_w = int(img_h * 0.2)
        pad_h = int(img_w * 0.2)

        input_x = tf.image.resize_image_with_crop_or_pad(input_x, img_h+pad_h, img_w+pad_w)
        input_x = tf.random_crop(input_x, [crop_height, crop_width, ch])
        input_x = tf.image.random_flip_left_right(input_x)
        input_x = tf.image.random_flip_up_down(input_x)

        input_x = tf.image.random_contrast(input_x, lower=0.2,upper=2.0)
        input_x = tf.image.random_brightness(input_x, max_delta=63. / 255.)
        input_x = tf.image.random_saturation(input_x, lower=0.5, upper=1.8)
        input_x = tf.image.per_image_standardization(input_x)
        return input_x

    def _aug_with_test(input_x, crop_height, crop_width):

        input_x = tf.image.resize_image_with_crop_or_pad(input_x, crop_height, crop_width)
        input_x = tf.image.per_image_standardization(input_x)
        return input_x

    image = tf.cond(is_training,
                    lambda: _aug_with_train(image, crop_h, crop_w),
                    lambda: _aug_with_test(image, crop_h, crop_w))
    return image

def images_augmentation(images, phase_train):
    with tf.name_scope('augmentation'):
        crop_h, crop_w = list(map(int, images.get_shape()[1:3]))
        images = tf.map_fn(lambda image : image_augmentation(image, phase_train, crop_h, crop_w),
                  images)
        return images

# %%
def batch_norm_(x, n_out, phase_train, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if len(x.get_shape()) == 4:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        elif len(x.get_shape()) == 2:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
            
        ema = tf.train.ExponentialMovingAverage(decay=0.5)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean),
                                     ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def residual_block(input_data, filters, strides, is_train, block_name) :
    #print('input_shape : ', input_data.shape)
    
    #he_init = tf.initializers.he_normal()

    with tf.variable_scope(block_name):
        # Layer1
        with tf.variable_scope('layer1'):
            layer = tf.layers.Conv2D(filters=filters, kernel_size = 3, use_bias=False,
                                   strides=strides, padding = 'SAME', activation=None)\
                                    (input_data)
            layer = batch_norm_(layer, filters, is_train)
            layer = tf.nn.relu(layer)
        
        # Layer2    
        with tf.variable_scope('layer2'):        
            layer = tf.layers.Conv2D(filters = filters, kernel_size = 3, use_bias=False,
                                   strides = strides, padding = 'SAME', activation=None)\
                                    (layer)
            layer = batch_norm_(layer, filters, is_train)
            layer = tf.nn.relu(layer)
        
        # Projection layer
        if input_data.shape[-1] != filters :
            input_data = tf.layers.Conv2D(filters = filters, kernel_size = 1, 
                                           strides = 1,
                                           padding='SAME',
                                           activation=tf.nn.relu
                                           )(input_data)

        return layer + input_data

# %%
graph1 = tf.Graph()
with graph1.as_default() :
    xs = tf.placeholder(dtype = tf.float32, shape=(None, 32, 32, 3))
    ys = tf.placeholder(dtype = tf.int64, shape=(None,))
    is_train = tf.placeholder_with_default(True, (), name='is_train')
    
    xs_aug = images_augmentation(xs, is_train)
    #he_init = tf.initializers.he_normal()
    
    layer = tf.layers.Conv2D(filters = 16, kernel_size = 3, strides=1, padding = 'SAME')(xs_aug)

    layer = residual_block(layer, 16, 1, is_train, 'resnet_1_1')
    layer = tf.layers.MaxPooling2D(2, 2)(layer)
    layer = residual_block(layer, 32, 1, is_train, 'resnet_2_1')
    layer = tf.layers.MaxPooling2D(2, 2)(layer)
    layer = residual_block(layer, 64, 1, is_train, 'resnet_3_1')
    layer = tf.layers.MaxPooling2D(2, 2)(layer)
    layer = residual_block(layer, 128, 1, is_train, 'resnet_4_1')
    layer = tf.layers.AveragePooling2D( (layer.get_shape()[1],layer.get_shape()[2]) , 1)(layer)
    
    layer = tf.layers.Flatten()(layer)
    logits = tf.layers.Dense(units = 10, activation = None)(layer)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 08:01:18.530786 140373342508928 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1514: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0706 08:01:18.573825 140373342508928 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
show_graph(graph1)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.5927269238883731&quot;).pbtxt = 'node {\n  name: &quot;Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 32\n        }\n        dim {\n          size: 32\n        }\n        dim {\n          size: 3\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Placeholder_1&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;is_train/input&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_BOOL\n        tensor_shape {\n        }\n        bool_val: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;is_train&quot;\n  op: &quot;PlaceholderWithDefault&quot;\n  input: &quot;is_train/input&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;Placeholder&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/strided_slice/stack&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/strided_slice/stack_1&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/strided_slice/stack_2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/strided_slice&quot;\n  op: &quot;StridedSlice&quot;\n  input: &quot;augmentation/map/Shape&quot;\n  input: &quot;augmentation/map/strided_slice/stack&quot;\n  input: &quot;augmentation/map/strided_slice/stack_1&quot;\n  input: &quot;augmentation/map/strided_slice/stack_2&quot;\n  attr {\n    key: &quot;Index&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;begin_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;ellipsis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;end_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;new_axis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;shrink_axis_mask&quot;\n    value {\n      i: 1\n    }\n  }\n}\nnode {\n  name: &quot;augmentation/map/TensorArray&quot;\n  op: &quot;TensorArrayV3&quot;\n  input: &quot;augmentation/map/strided_slice&quot;\n  attr {\n    key: &quot;clear_after_read&quot;\n     ...

# %%
 with graph1.as_default() :
    with tf.variable_scope('loss') :
        weight_decay = 5e-4
        sce = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = ys,
                                                      logits = logits)
        weights = graph1.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                                       scope='^.*/kernel.*$')
        l2_loss = tf.add_n([tf.nn.l2_loss(weight) 
                           for weight in weights])
        loss = tf.reduce_mean(sce, name='loss') + l2_loss * weight_decay
    loss = tf.identity(loss, name='loss')

# %%
with graph1.as_default() :
    with tf.variable_scope('metric_acc') :
        pred_val = tf.argmax(logits,axis=1)
        acc = tf.reduce_mean(tf.cast(tf.equal(pred_val, ys), tf.float32))

# %%
with graph1.as_default() :
    momentum = 0.9
    lr = tf.placeholder(tf.float32, (), name='learning_rate')    
    global_step = tf.train.get_or_create_global_step()
    with tf.variable_scope("optimizer"):
        train_op = (tf.train.MomentumOptimizer(lr, momentum = momentum)\
                .minimize(loss, global_step=global_step))

# %%
with graph1.as_default() :
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    provider = DataProvider(train_x, train_y)
    loss_list = []
    acc_list = []
    loss_val_list = []
    acc_val_list = []
    j = 0
    
    for i in range(10000) :
        data, label = provider.next_batch(100)
        
        sess.run(train_op, {xs : data, ys : label, is_train : True, lr : 0.01})
        
        if i % 100 == 0 :
            
            loss_val, acc_val = sess.run([loss, acc],
                                                  feed_dict = { xs : test_x,
                                                               ys : test_y,
                                                              is_train : False})
            
            data, label = provider.next_batch(10000)
            loss_, acc_ = sess.run([loss, acc],
                                              feed_dict = {xs : data,
                                                          ys : label,
                                                          is_train : False})
            loss_list.append(loss_)
            acc_list.append(acc_)
            loss_val_list.append(loss_val)
            acc_val_list.append(acc_val)
            
            print('step : {}, train_loss : {:5.3}, train_acc : {:5.3}, vali_loss : {:5.3}, vali_acc : {:5.3}'.\
                  format(i,loss_, acc_, loss_val, acc_val))
# Out:
# step : 0, train_loss :  48.2, train_acc : 0.0993, vali_loss :  48.3, vali_acc :   0.1
# step : 100, train_loss :  1.88, train_acc : 0.354, vali_loss :  1.87, vali_acc : 0.362
# step : 200, train_loss :  1.86, train_acc : 0.384, vali_loss :  1.87, vali_acc : 0.384
# step : 300, train_loss :  1.69, train_acc : 0.452, vali_loss :  1.72, vali_acc :  0.44
# step : 400, train_loss :  1.51, train_acc : 0.509, vali_loss :  1.51, vali_acc : 0.509
# step : 500, train_loss :  1.52, train_acc : 0.509, vali_loss :   1.5, vali_acc : 0.517
# step : 600, train_loss :   1.4, train_acc : 0.551, vali_loss :  1.39, vali_acc : 0.553
# step : 700, train_loss :   1.4, train_acc : 0.541, vali_loss :  1.41, vali_acc : 0.545
# step : 800, train_loss :  1.32, train_acc : 0.584, vali_loss :  1.35, vali_acc : 0.574
# step : 900, train_loss :  1.31, train_acc :  0.58, vali_loss :  1.34, vali_acc : 0.571
# step : 1000, train_loss :  1.36, train_acc : 0.572, vali_loss :  1.36, vali_acc :  0.57
# step : 1100, train_loss :  1.25, train_acc : 0.602, vali_loss :  1.25, vali_acc : 0.601
# step : 1200, train_loss :  1.21, train_acc : 0.612, vali_loss :  1.23, vali_acc : 0.614
# step : 1300, train_loss :  1.15, train_acc : 0.641, vali_loss :  1.19, vali_acc : 0.633
# step : 1400, train_loss :  1.17, train_acc : 0.633, vali_loss :  1.22, vali_acc : 0.623
# step : 1500, train_loss :  1.16, train_acc : 0.641, vali_loss :  1.17, vali_acc : 0.638
# step : 1600, train_loss :  1.14, train_acc : 0.643, vali_loss :  1.14, vali_acc : 0.641
# step : 1700, train_loss :  1.11, train_acc : 0.649, vali_loss :  1.14, vali_acc : 0.648
# step : 1800, train_loss :  1.13, train_acc : 0.651, vali_loss :  1.16, vali_acc : 0.641
# step : 1900, train_loss :  1.09, train_acc : 0.663, vali_loss :  1.14, vali_acc : 0.644
# step : 2000, train_loss :  1.13, train_acc : 0.651, vali_loss :  1.15, vali_acc :  0.64
# step : 2100, train_loss :  1.06, train_acc : 0.671, vali_loss :  1.07, vali_acc : 0.669
# step : 2200, train_loss :  1.05, train_acc : 0.681, vali_loss :  1.08, vali_acc : 0.672
# step : 2300, train_loss :  1.04, train_acc : 0.678, vali_loss :  1.08, vali_acc : 0.668
# step : 2400, train_loss :   1.0, train_acc : 0.696, vali_loss :  1.06, vali_acc : 0.676
# step : 2500, train_loss :  1.05, train_acc : 0.683, vali_loss :  1.06, vali_acc : 0.673
# step : 2600, train_loss :  1.02, train_acc :  0.69, vali_loss :  1.03, vali_acc : 0.685
# step : 2700, train_loss : 0.993, train_acc : 0.692, vali_loss :  1.03, vali_acc : 0.682
# step : 2800, train_loss :  0.98, train_acc : 0.708, vali_loss :  1.01, vali_acc : 0.692
# step : 2900, train_loss :  1.01, train_acc : 0.691, vali_loss :  1.06, vali_acc : 0.676
# step : 3000, train_loss :  1.05, train_acc : 0.679, vali_loss :  1.07, vali_acc : 0.676
# step : 3100, train_loss :  1.03, train_acc : 0.687, vali_loss :  1.04, vali_acc :  0.68
# step : 3200, train_loss : 0.966, train_acc : 0.707, vali_loss :  1.01, vali_acc :  0.69
# step : 3300, train_loss : 0.957, train_acc : 0.716, vali_loss : 0.991, vali_acc :   0.7
# step : 3400, train_loss : 0.935, train_acc :  0.72, vali_loss : 0.984, vali_acc : 0.705
# step : 3500, train_loss : 0.988, train_acc : 0.698, vali_loss :  1.02, vali_acc : 0.686
# step : 3600, train_loss : 0.993, train_acc : 0.697, vali_loss :   1.0, vali_acc : 0.696
# step : 3700, train_loss : 0.944, train_acc : 0.719, vali_loss : 0.992, vali_acc : 0.702
# step : 3800, train_loss : 0.911, train_acc : 0.729, vali_loss : 0.961, vali_acc : 0.711
# step : 3900, train_loss : 0.916, train_acc : 0.729, vali_loss : 0.973, vali_acc :  0.71
# step : 4000, train_loss : 0.927, train_acc : 0.723, vali_loss : 0.943, vali_acc : 0.716
# step : 4100, train_loss : 0.915, train_acc : 0.727, vali_loss : 0.944, vali_acc : 0.714
# step : 4200, train_loss : 0.893, train_acc : 0.733, vali_loss :  0.93, vali_acc : 0.717
# step : 4300, train_loss :   0.9, train_acc : 0.737, vali_loss : 0.951, vali_acc : 0.717
# step : 4400, train_loss : 0.887, train_acc : 0.736, vali_loss : 0.941, vali_acc : 0.718
# step : 4500, train_loss : 0.883, train_acc : 0.739, vali_loss : 0.894, vali_acc : 0.736
# step : 4600, train_loss : 0.916, train_acc : 0.729, vali_loss : 0.945, vali_acc : 0.715
# step : 4700, train_loss : 0.862, train_acc : 0.748, vali_loss : 0.906, vali_acc : 0.731
# step : 4800, train_loss : 0.879, train_acc : 0.743, vali_loss :  0.93, vali_acc : 0.721
# step : 4900, train_loss : 0.875, train_acc : 0.741, vali_loss : 0.933, vali_acc :  0.72
# step : 5000, train_loss : 0.869, train_acc : 0.746, vali_loss : 0.896, vali_acc : 0.734
# step : 5100, train_loss : 0.901, train_acc : 0.735, vali_loss : 0.937, vali_acc :  0.72
# step : 5200, train_loss : 0.845, train_acc : 0.748, vali_loss :   0.9, vali_acc : 0.731
# step : 5300, train_loss : 0.841, train_acc : 0.753, vali_loss : 0.889, vali_acc : 0.734
# step : 5400, train_loss :  0.85, train_acc : 0.752, vali_loss : 0.912, vali_acc : 0.727
# step : 5500, train_loss : 0.856, train_acc : 0.745, vali_loss : 0.881, vali_acc : 0.739
# step : 5600, train_loss : 0.849, train_acc : 0.752, vali_loss :  0.87, vali_acc : 0.739
# step : 5700, train_loss :  0.85, train_acc : 0.748, vali_loss : 0.899, vali_acc : 0.731
# step : 5800, train_loss :  0.82, train_acc : 0.764, vali_loss : 0.877, vali_acc : 0.742
# step : 5900, train_loss : 0.832, train_acc : 0.757, vali_loss : 0.886, vali_acc : 0.738
# step : 6000, train_loss : 0.855, train_acc :  0.75, vali_loss : 0.885, vali_acc : 0.737
# step : 6100, train_loss : 0.852, train_acc : 0.753, vali_loss : 0.884, vali_acc : 0.738
# step : 6200, train_loss : 0.794, train_acc : 0.771, vali_loss : 0.855, vali_acc : 0.751
# step : 6300, train_loss : 0.789, train_acc : 0.771, vali_loss : 0.862, vali_acc : 0.752
# step : 6400, train_loss : 0.806, train_acc : 0.765, vali_loss : 0.872, vali_acc : 0.743
# step : 6500, train_loss :  0.82, train_acc : 0.767, vali_loss : 0.858, vali_acc :  0.75
# step : 6600, train_loss : 0.831, train_acc : 0.759, vali_loss : 0.869, vali_acc : 0.743
# step : 6700, train_loss : 0.787, train_acc : 0.775, vali_loss :  0.86, vali_acc : 0.748
# step : 6800, train_loss : 0.783, train_acc :  0.78, vali_loss :  0.85, vali_acc : 0.752
# step : 6900, train_loss : 0.821, train_acc : 0.761, vali_loss : 0.883, vali_acc : 0.739
# step : 7000, train_loss : 0.833, train_acc : 0.758, vali_loss : 0.873, vali_acc : 0.742
# step : 7100, train_loss : 0.822, train_acc : 0.759, vali_loss : 0.863, vali_acc : 0.746
# step : 7200, train_loss : 0.769, train_acc : 0.779, vali_loss : 0.838, vali_acc : 0.756
# step : 7300, train_loss : 0.785, train_acc : 0.772, vali_loss : 0.855, vali_acc : 0.752
# step : 7400, train_loss : 0.796, train_acc : 0.769, vali_loss : 0.862, vali_acc : 0.746
# step : 7500, train_loss : 0.799, train_acc : 0.769, vali_loss : 0.845, vali_acc : 0.757
# step : 7600, train_loss : 0.813, train_acc : 0.769, vali_loss : 0.864, vali_acc : 0.751
# step : 7700, train_loss : 0.742, train_acc : 0.787, vali_loss : 0.819, vali_acc : 0.764
# step : 7800, train_loss : 0.759, train_acc :  0.78, vali_loss : 0.826, vali_acc : 0.761
# step : 7900, train_loss : 0.775, train_acc : 0.777, vali_loss : 0.837, vali_acc : 0.753
# step : 8000, train_loss : 0.794, train_acc : 0.771, vali_loss : 0.841, vali_acc : 0.753
# step : 8100, train_loss : 0.781, train_acc : 0.776, vali_loss : 0.823, vali_acc : 0.758
# step : 8200, train_loss : 0.728, train_acc : 0.793, vali_loss : 0.796, vali_acc : 0.771
# step : 8300, train_loss : 0.755, train_acc : 0.784, vali_loss : 0.828, vali_acc : 0.761
# step : 8400, train_loss : 0.723, train_acc : 0.795, vali_loss : 0.785, vali_acc : 0.776
# step : 8500, train_loss : 0.799, train_acc : 0.766, vali_loss : 0.837, vali_acc : 0.756
# step : 8600, train_loss : 0.776, train_acc : 0.776, vali_loss : 0.817, vali_acc : 0.764
# step : 8700, train_loss : 0.737, train_acc : 0.787, vali_loss : 0.821, vali_acc : 0.766
# step : 8800, train_loss : 0.755, train_acc : 0.786, vali_loss : 0.825, vali_acc : 0.763
# step : 8900, train_loss : 0.727, train_acc : 0.796, vali_loss : 0.807, vali_acc :  0.77
# step : 9000, train_loss :  0.76, train_acc : 0.781, vali_loss : 0.809, vali_acc : 0.767
# step : 9100, train_loss : 0.792, train_acc : 0.774, vali_loss : 0.837, vali_acc : 0.758
# step : 9200, train_loss : 0.717, train_acc : 0.797, vali_loss : 0.798, vali_acc : 0.773
# step : 9300, train_loss : 0.742, train_acc : 0.788, vali_loss : 0.814, vali_acc : 0.766
# step : 9400, train_loss : 0.752, train_acc : 0.786, vali_loss : 0.813, vali_acc : 0.768
# step : 9500, train_loss : 0.748, train_acc : 0.789, vali_loss : 0.792, vali_acc : 0.774
# step : 9600, train_loss : 0.762, train_acc :  0.78, vali_loss : 0.807, vali_acc : 0.766
# step : 9700, train_loss : 0.716, train_acc : 0.798, vali_loss : 0.801, vali_acc : 0.775
# step : 9800, train_loss :  0.71, train_acc : 0.799, vali_loss : 0.789, vali_acc : 0.775
# step : 9900, train_loss : 0.738, train_acc : 0.792, vali_loss : 0.816, vali_acc : 0.769

# %%
with graph1.as_default() :
   
    for i in range(10000, 20000) :
        data, label = provider.next_batch(100)
        
        sess.run(train_op, {xs : data, ys : label, is_train : True, lr : 0.001})
        
        if i % 100 == 0 :
            
            loss_val, acc_val = sess.run([loss, acc],
                                                  feed_dict = { xs : test_x,
                                                               ys : test_y,
                                                              is_train : False})
            
            data, label = provider.next_batch(10000)
            loss_, acc_ = sess.run([loss, acc],
                                              feed_dict = {xs : data,
                                                          ys : label,
                                                          is_train : False})
            loss_list.append(loss_)
            acc_list.append(acc_)
            loss_val_list.append(loss_val)
            acc_val_list.append(acc_val)
            
            print('step : {}, train_loss : {:5.3}, train_acc : {:5.3}, vali_loss : {:5.3}, vali_acc : {:5.3}'.\
                  format(i,loss_, acc_, loss_val, acc_val))
# Out:
# step : 10000, train_loss : 0.605, train_acc : 0.838, vali_loss : 0.684, vali_acc : 0.807
# step : 10100, train_loss : 0.607, train_acc : 0.834, vali_loss : 0.677, vali_acc : 0.808
# step : 10200, train_loss : 0.584, train_acc : 0.841, vali_loss : 0.684, vali_acc : 0.806
# step : 10300, train_loss :  0.59, train_acc : 0.837, vali_loss : 0.676, vali_acc :  0.81
# step : 10400, train_loss : 0.576, train_acc : 0.844, vali_loss : 0.678, vali_acc : 0.809
# step : 10500, train_loss : 0.593, train_acc : 0.839, vali_loss : 0.687, vali_acc : 0.807
# step : 10600, train_loss :  0.58, train_acc : 0.843, vali_loss : 0.675, vali_acc :  0.81
# step : 10700, train_loss : 0.607, train_acc : 0.835, vali_loss : 0.684, vali_acc : 0.808
# step : 10800, train_loss : 0.611, train_acc : 0.834, vali_loss : 0.681, vali_acc : 0.809
# step : 10900, train_loss : 0.573, train_acc : 0.847, vali_loss : 0.672, vali_acc : 0.813
# step : 11000, train_loss : 0.586, train_acc : 0.841, vali_loss : 0.681, vali_acc : 0.811
# step : 11100, train_loss : 0.575, train_acc : 0.847, vali_loss : 0.672, vali_acc : 0.812
# step : 11200, train_loss : 0.606, train_acc : 0.836, vali_loss : 0.685, vali_acc :  0.81
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5806876b40f0> in <module>()
#      17                                               feed_dict = {xs : data,
#      18                                                           ys : label,
# ---> 19                                                           is_train : False})
#      20             loss_list.append(loss_)
#      21             acc_list.append(acc_)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
with graph1.as_default() :
   
    for i in range(11300, 20000) :
        data, label = provider.next_batch(100)
        
        sess.run(train_op, {xs : data, ys : label, is_train : True, lr : 0.0001})
        
        if i % 100 == 0 :
            
            loss_val, acc_val = sess.run([loss, acc],
                                                  feed_dict = { xs : test_x,
                                                               ys : test_y,
                                                              is_train : False})
            
            data, label = provider.next_batch(10000)
            loss_, acc_ = sess.run([loss, acc],
                                              feed_dict = {xs : data,
                                                          ys : label,
                                                          is_train : False})
            loss_list.append(loss_)
            acc_list.append(acc_)
            loss_val_list.append(loss_val)
            acc_val_list.append(acc_val)
            
            print('step : {}, train_loss : {:5.3}, train_acc : {:5.3}, vali_loss : {:5.3}, vali_acc : {:5.3}'.\
                  format(i,loss_, acc_, loss_val, acc_val))
# Out:
# step : 11300, train_loss : 0.564, train_acc : 0.849, vali_loss : 0.668, vali_acc : 0.811
# step : 11400, train_loss : 0.583, train_acc : 0.841, vali_loss : 0.683, vali_acc : 0.806
# step : 11500, train_loss :  0.58, train_acc : 0.846, vali_loss : 0.674, vali_acc : 0.811
# step : 11600, train_loss : 0.604, train_acc : 0.837, vali_loss : 0.682, vali_acc : 0.808
# step : 11700, train_loss : 0.602, train_acc : 0.838, vali_loss : 0.673, vali_acc : 0.811
# step : 11800, train_loss : 0.564, train_acc : 0.848, vali_loss :  0.67, vali_acc : 0.814
# step : 11900, train_loss : 0.578, train_acc : 0.843, vali_loss : 0.678, vali_acc : 0.809
# step : 12000, train_loss : 0.576, train_acc : 0.847, vali_loss : 0.669, vali_acc : 0.813
# step : 12100, train_loss : 0.601, train_acc : 0.839, vali_loss : 0.679, vali_acc : 0.808
# step : 12200, train_loss : 0.599, train_acc : 0.838, vali_loss : 0.671, vali_acc : 0.812
# step : 12300, train_loss :  0.56, train_acc : 0.851, vali_loss : 0.666, vali_acc : 0.815
# step : 12400, train_loss : 0.576, train_acc : 0.843, vali_loss : 0.675, vali_acc :  0.81
# step : 12500, train_loss : 0.572, train_acc : 0.848, vali_loss : 0.666, vali_acc : 0.813
# step : 12600, train_loss :   0.6, train_acc : 0.839, vali_loss : 0.679, vali_acc :  0.81
# step : 12700, train_loss :   0.6, train_acc : 0.838, vali_loss :  0.67, vali_acc : 0.811
# step : 12800, train_loss : 0.561, train_acc : 0.851, vali_loss : 0.667, vali_acc : 0.813
# step : 12900, train_loss : 0.573, train_acc : 0.845, vali_loss : 0.671, vali_acc : 0.811
# step : 13000, train_loss : 0.572, train_acc : 0.847, vali_loss : 0.667, vali_acc : 0.812
# step : 13100, train_loss :   0.6, train_acc : 0.837, vali_loss : 0.679, vali_acc : 0.812
# step : 13200, train_loss : 0.597, train_acc : 0.836, vali_loss : 0.669, vali_acc : 0.814
# step : 13300, train_loss :  0.56, train_acc : 0.851, vali_loss : 0.667, vali_acc : 0.813
# step : 13400, train_loss : 0.577, train_acc : 0.845, vali_loss : 0.675, vali_acc :  0.81
# step : 13500, train_loss : 0.573, train_acc : 0.847, vali_loss : 0.668, vali_acc : 0.812
# step : 13600, train_loss : 0.597, train_acc : 0.839, vali_loss : 0.675, vali_acc : 0.811
# step : 13700, train_loss : 0.594, train_acc : 0.839, vali_loss : 0.664, vali_acc : 0.812
# step : 13800, train_loss : 0.558, train_acc : 0.852, vali_loss : 0.663, vali_acc : 0.813
# step : 13900, train_loss : 0.577, train_acc : 0.844, vali_loss : 0.676, vali_acc : 0.809
# step : 14000, train_loss : 0.571, train_acc : 0.847, vali_loss : 0.666, vali_acc : 0.814
# step : 14100, train_loss : 0.597, train_acc :  0.84, vali_loss : 0.676, vali_acc :  0.81
# step : 14200, train_loss : 0.598, train_acc : 0.836, vali_loss : 0.668, vali_acc :  0.81
# step : 14300, train_loss : 0.557, train_acc :  0.85, vali_loss : 0.663, vali_acc : 0.814
# step : 14400, train_loss :  0.57, train_acc : 0.847, vali_loss : 0.669, vali_acc : 0.811
# step : 14500, train_loss : 0.568, train_acc : 0.849, vali_loss : 0.663, vali_acc : 0.812
# step : 14600, train_loss :  0.59, train_acc : 0.842, vali_loss : 0.669, vali_acc : 0.812
# step : 14700, train_loss : 0.591, train_acc :  0.84, vali_loss : 0.663, vali_acc : 0.812
# step : 14800, train_loss : 0.556, train_acc : 0.852, vali_loss : 0.662, vali_acc : 0.814
# step : 14900, train_loss : 0.569, train_acc : 0.847, vali_loss : 0.668, vali_acc : 0.812
# step : 15000, train_loss : 0.568, train_acc : 0.848, vali_loss : 0.662, vali_acc : 0.813
# step : 15100, train_loss : 0.591, train_acc : 0.843, vali_loss :  0.67, vali_acc : 0.812
# step : 15200, train_loss : 0.589, train_acc :  0.84, vali_loss : 0.661, vali_acc : 0.814
# step : 15300, train_loss : 0.555, train_acc : 0.853, vali_loss : 0.661, vali_acc : 0.814
# step : 15400, train_loss : 0.573, train_acc : 0.845, vali_loss : 0.672, vali_acc : 0.811
# step : 15500, train_loss : 0.567, train_acc : 0.849, vali_loss : 0.662, vali_acc : 0.813
# step : 15600, train_loss :  0.59, train_acc : 0.842, vali_loss :  0.67, vali_acc : 0.811
# step : 15700, train_loss : 0.595, train_acc : 0.838, vali_loss : 0.667, vali_acc : 0.811
# step : 15800, train_loss : 0.555, train_acc : 0.852, vali_loss : 0.661, vali_acc : 0.814
# step : 15900, train_loss :  0.57, train_acc : 0.847, vali_loss :  0.67, vali_acc : 0.811
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a3c3ab57b538> in <module>()
#      17                                               feed_dict = {xs : data,
#      18                                                           ys : label,
# ---> 19                                                           is_train : False})
#      20             loss_list.append(loss_)
#      21             acc_list.append(acc_)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
with graph1.as_default() :
   
    for i in range(16000, 20000) :
        data, label = provider.next_batch(100)
        
        sess.run(train_op, {xs : data, ys : label, is_train : True, lr : 0.00001})
        
        if i % 100 == 0 :
            
            loss_val, acc_val = sess.run([loss, acc],
                                                  feed_dict = { xs : test_x,
                                                               ys : test_y,
                                                              is_train : False})
            
            data, label = provider.next_batch(10000)
            loss_, acc_ = sess.run([loss, acc],
                                              feed_dict = {xs : data,
                                                          ys : label,
                                                          is_train : False})
            loss_list.append(loss_)
            acc_list.append(acc_)
            loss_val_list.append(loss_val)
            acc_val_list.append(acc_val)
            
            print('step : {}, train_loss : {:5.3}, train_acc : {:5.3}, vali_loss : {:5.3}, vali_acc : {:5.3}'.\
                  format(i,loss_, acc_, loss_val, acc_val))
# Out:
# step : 16000, train_loss : 0.559, train_acc : 0.853, vali_loss : 0.664, vali_acc : 0.814
# step : 16100, train_loss : 0.575, train_acc : 0.845, vali_loss : 0.675, vali_acc :  0.81
# step : 16200, train_loss : 0.556, train_acc : 0.852, vali_loss : 0.661, vali_acc : 0.813
# step : 16300, train_loss : 0.573, train_acc : 0.845, vali_loss : 0.673, vali_acc : 0.811
# step : 16400, train_loss : 0.571, train_acc : 0.848, vali_loss : 0.667, vali_acc : 0.814
# step : 16500, train_loss : 0.588, train_acc : 0.842, vali_loss : 0.669, vali_acc : 0.813
# step : 16600, train_loss : 0.592, train_acc : 0.838, vali_loss : 0.665, vali_acc : 0.813
# step : 16700, train_loss : 0.559, train_acc : 0.851, vali_loss : 0.665, vali_acc : 0.813
# step : 16800, train_loss :  0.57, train_acc : 0.847, vali_loss :  0.67, vali_acc : 0.811
# step : 16900, train_loss : 0.569, train_acc : 0.849, vali_loss : 0.663, vali_acc : 0.813
# step : 17000, train_loss : 0.591, train_acc : 0.841, vali_loss : 0.672, vali_acc : 0.812
# step : 17100, train_loss : 0.591, train_acc :  0.84, vali_loss : 0.665, vali_acc : 0.811
# step : 17200, train_loss : 0.554, train_acc : 0.852, vali_loss :  0.66, vali_acc : 0.814
# step : 17300, train_loss : 0.568, train_acc : 0.848, vali_loss : 0.667, vali_acc : 0.813
# step : 17400, train_loss : 0.571, train_acc : 0.848, vali_loss : 0.668, vali_acc : 0.811
# step : 17500, train_loss : 0.595, train_acc : 0.839, vali_loss : 0.675, vali_acc : 0.809
# step : 17600, train_loss : 0.593, train_acc : 0.837, vali_loss : 0.666, vali_acc : 0.812
# step : 17700, train_loss : 0.557, train_acc : 0.851, vali_loss : 0.661, vali_acc : 0.813
# step : 17800, train_loss :  0.57, train_acc : 0.846, vali_loss : 0.671, vali_acc : 0.811
# step : 17900, train_loss : 0.569, train_acc : 0.848, vali_loss : 0.664, vali_acc : 0.812
# step : 18000, train_loss : 0.592, train_acc : 0.841, vali_loss : 0.672, vali_acc : 0.812
# step : 18100, train_loss : 0.588, train_acc :  0.84, vali_loss :  0.66, vali_acc : 0.813
# step : 18200, train_loss : 0.557, train_acc : 0.853, vali_loss : 0.663, vali_acc : 0.813
# step : 18300, train_loss :  0.57, train_acc : 0.846, vali_loss :  0.67, vali_acc : 0.812
# step : 18400, train_loss : 0.568, train_acc : 0.848, vali_loss : 0.664, vali_acc : 0.813
# step : 18500, train_loss : 0.591, train_acc : 0.842, vali_loss : 0.672, vali_acc :  0.81
# step : 18600, train_loss : 0.592, train_acc : 0.839, vali_loss : 0.666, vali_acc : 0.812
# step : 18700, train_loss : 0.559, train_acc : 0.851, vali_loss : 0.664, vali_acc : 0.812
# step : 18800, train_loss :  0.57, train_acc : 0.847, vali_loss : 0.669, vali_acc : 0.812
# step : 18900, train_loss : 0.568, train_acc : 0.847, vali_loss : 0.663, vali_acc : 0.814
# step : 19000, train_loss :  0.59, train_acc : 0.842, vali_loss :  0.67, vali_acc : 0.813
# step : 19100, train_loss : 0.592, train_acc :  0.84, vali_loss : 0.665, vali_acc : 0.811
# step : 19200, train_loss : 0.558, train_acc : 0.851, vali_loss : 0.664, vali_acc : 0.812
# step : 19300, train_loss : 0.571, train_acc : 0.848, vali_loss :  0.67, vali_acc : 0.813
# step : 19400, train_loss : 0.566, train_acc : 0.848, vali_loss : 0.662, vali_acc : 0.813
# step : 19500, train_loss : 0.594, train_acc : 0.839, vali_loss : 0.676, vali_acc : 0.813
# step : 19600, train_loss : 0.592, train_acc : 0.839, vali_loss : 0.666, vali_acc : 0.812
# step : 19700, train_loss : 0.558, train_acc : 0.851, vali_loss : 0.664, vali_acc : 0.813
# step : 19800, train_loss :  0.57, train_acc : 0.846, vali_loss : 0.671, vali_acc : 0.811
# step : 19900, train_loss : 0.568, train_acc : 0.849, vali_loss : 0.664, vali_acc : 0.814

# %%
plt.title('Loss Comparison based on ResNet')
plt.xlabel('Iteration')
plt.ylabel('Loss(CEE)')
plt.plot(loss_list[10:], 'r--', label = 'ResNet_train_loss')
plt.plot(loss_val_list[10:], 'b--o', markersize=1, markeredgecolor='b', label = 'ResNet_test_loss')
plt.legend()
plt.show()

# %%
plt.title('Acc Comparison based on ResNet')
plt.xlabel('Iteration')
plt.ylabel('Accuacry')
plt.plot(acc_list[10:], color='r', linestyle='--',
         label = 'ResNet_train_acc')
plt.plot(acc_val_list[10:],color='b', linestyle='--', markersize=1, markeredgecolor='b', label = 'ResNet_test_acc')
plt.legend()
